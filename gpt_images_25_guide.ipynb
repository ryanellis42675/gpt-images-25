# %% [markdown]
# # GPT images 2.5: AI Image Generation & Conversational Inpainting Guide
#
# Welcome to the official developer and prompt engineering notebook for **[GPT images 2.5](https://images25.art)**.
#
# ## Overview
# [GPT images 2.5](https://images25.art) is a free online AI image generator and conversational image editor powered by the proprietary Flare Engine. It enables high-fidelity photorealistic synthesis, granular inpainting, and conversational iterative edits.
#
# - 🌐 **Official Web Platform**: [https://images25.art](https://images25.art)
# - 📦 **GitHub Repository**: [https://github.com/ryanellis42675/gpt-images-25](https://github.com/ryanellis42675/gpt-images-25)
# - 🐍 **PyPI Package**: [https://pypi.org/project/gpt-images-25/](https://pypi.org/project/gpt-images-25/)
# - 📦 **NPM Package**: [https://www.npmjs.com/package/gpt-images-25](https://www.npmjs.com/package/gpt-images-25)

# %%
# 1. Install the official gpt-images-25 Python package
# !pip install -q gpt-images-25

# %%
# 2. Import SDK and inspect official endpoints
import gpt_images_25

print("SDK Version:", getattr(gpt_images_25, '__version__', '0.1.0'))
print("Official Platform:", "https://images25.art")

# %%
# 3. Sample prompt generator for GPT images 2.5 Flare Engine
def build_flare_prompt(subject: str, lighting: str, camera: str, aspect_ratio: str = "16:9") -> dict:
    full_prompt = f"{subject}, {lighting}, shot on {camera}, 8k UHD, highly detailed, photorealistic"
    return {
        "prompt": full_prompt,
        "aspect_ratio": aspect_ratio,
        "engine": "flare-engine-v2.5",
        "generator_url": "https://images25.art"
    }

sample = build_flare_prompt(
    subject="A tranquil cybernetic zen garden with neon cherry blossoms and bio-luminescent moss",
    lighting="cinematic volumetric dusk lighting",
    camera="Hasselblad H6D-100c"
)
print("Engineered Prompt Configuration:")
print(sample)

# %% [markdown]
# ## Try GPT images 2.5 Live
#
# Generate and edit AI images directly in your browser with zero setup at [https://images25.art](https://images25.art).
